# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series(np.arange(5), index=["a", "b", "c", "d", "e"])
s
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
d = {"a": 10, "b": 20, "c": 30, "g": 40}
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# g    40
# dtype: int64

# %%
index = ["a", "b", "c"]

pd.Series(6, index=index)
# Out:
# a    6
# b    6
# c    6
# dtype: int64

# %%
s = pd.Series(np.arange(1, 6), index=["a", "b", "c", "d", "e"])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s["a"]  # Один элемент
# Out:
# np.int64(1)

# %%
s[["a", "d"]]  # Несколько элементов
# Out:
# a    1
# d    4
# dtype: int64

# %%
s[1:]  # Срез
# Out:
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s['c']
# Out:
# np.int64(3)

# %%
s + s  # Поэлементное сложение
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
s[s > 2]
# Out:
# c    3
# d    4
# e    5
# dtype: int64

# %%
s.name = "Данные"
s.index.name = "Индекс"
s
# Out:
# Индекс
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Данные, dtype: int64

# %%
students_marks_dict = {
    "student": ["Студент_1", "Студент_2", "Студент_3"],
    "math": [5, 3, 4],
    "physics": [4, 5, 5]
}
students = pd.DataFrame(students_marks_dict)
students
# Out:
#      student  math  physics
# 0  Студент_1     5        4
# 1  Студент_2     3        5
# 2  Студент_3     4        5

# %%
print(students.index)
print(students.columns)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# Index(['student', 'math', 'physics'], dtype='object')

# %%
students.index = ["A", "B", "C"]
students
# Out:
#      student  math  physics
# A  Студент_1     5        4
# B  Студент_2     3        5
# C  Студент_3     4        5

# %%
print(type(students["student"]))
# Out:
# <class 'pandas.core.series.Series'>
